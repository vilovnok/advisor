# %%
# !pip install --upgrade langchain-mistralai

# %%
from langchain_mistralai import ChatMistralAI


chat = ChatMistralAI(
            model="mistral-large-latest",
            temperature=0.5,
            max_retries=2,
            api_key="vyhXlcO3zjBdbeHD0mmNMQf4PlBtIlM4"
        )
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_mistralai import ChatMistralAI
#       4 chat = ChatMistralAI(
#       5             model="mistral-large-latest",
#       6             temperature=0.5,
#       7             max_retries=2,
#       8             api_key="vyhXlcO3zjBdbeHD0mmNMQf4PlBtIlM4"
#       9         )
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/langchain_mistralai/__init__.py:1
# ----> 1 from langchain_mistralai.chat_models import ChatMistralAI
#       2 from langchain_mistralai.embeddings import MistralAIEmbeddings
#       4 __all__ = ["ChatMistralAI", "MistralAIEmbeddings"]
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/langchain_mistralai/chat_models.py:361
#     357     else:
#     358         raise ValueError(f"Got unknown type {message}")
# --> 361 class ChatMistralAI(BaseChatModel):
#     362     """A chat model that uses the MistralAI API."""
#     364     client: httpx.Client = Field(default=None, exclude=True)  #: :meta private:
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/main.py:221, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     219 elif is_valid_field(var_name) and var_name not in annotations and can_be_changed:
#     220     validate_field_name(bases, var_name)
# --> 221     inferred = ModelField.infer(
#     222         name=var_name,
#     223         value=value,
#     224         annotation=annotations.get(var_name, Undefined),
#     225         class_validators=vg.get_validators(var_name),
#     226         config=config,
#     227     )
#     228     if var_name in fields:
#     229         if lenient_issubclass(inferred.type_, fields[var_name].type_):
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/fields.py:504, in ModelField.infer(cls, name, value, annotation, class_validators, config)
#     501     required = False
#     502 annotation = get_annotation_from_field_info(annotation, field_info, name, config.validate_assignment)
# --> 504 return cls(
#     505     name=name,
#     506     type_=annotation,
#     507     alias=field_info.alias,
#     508     class_validators=class_validators,
#     509     default=value,
#     510     default_factory=field_info.default_factory,
#     511     required=required,
#     512     model_config=config,
#     513     field_info=field_info,
#     514 )
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/fields.py:434, in ModelField.__init__(self, name, type_, class_validators, model_config, default, default_factory, required, final, alias, field_info)
#     432 self.shape: int = SHAPE_SINGLETON
#     433 self.model_config.prepare_field(self)
# --> 434 self.prepare()
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/fields.py:544, in ModelField.prepare(self)
#     537 def prepare(self) -> None:
#     538     """
#     539     Prepare the field but inspecting self.default, self.type_ etc.
#     540
#     541     Note: this method is **not** idempotent (because _type_analysis is not idempotent),
#     542     e.g. calling it it multiple times may modify the field and configure it incorrectly.
#     543     """
# --> 544     self._set_default_and_type()
#     545     if self.type_.__class__ is ForwardRef or self.type_.__class__ is DeferredType:
#     546         # self.type_ is currently a ForwardRef and there's nothing we can do now,
#     547         # user will need to call model.update_forward_refs()
#     548         return
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/fields.py:568, in ModelField._set_default_and_type(self)
#     563         raise errors_.ConfigError(
#     564             f'you need to set the type of field {self.name!r} when using `default_factory`'
#     565         )
#     566     return
# --> 568 default_value = self.get_default()
#     570 if default_value is not None and self.type_ is Undefined:
#     571     self.type_ = default_value.__class__
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/fields.py:437, in ModelField.get_default(self)
#     436 def get_default(self) -> Any:
# --> 437     return smart_deepcopy(self.default) if self.default_factory is None else self.default_factory()
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/v1/utils.py:694, in smart_deepcopy(obj)
#     690 except (TypeError, ValueError, RuntimeError):
#     691     # do we really dare to catch ALL errors? Seems a bit risky
#     692     pass
# --> 694 return deepcopy(obj)
#
# File ~/anaconda3/envs/ml/lib/python3.9/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/envs/ml/lib/python3.9/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if deep:
#     270     state = deepcopy(state, memo)
# --> 271 if hasattr(y, '__setstate__'):
#     272     y.__setstate__(state)
#     273 else:
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/_internal/_decorators.py:206, in PydanticDescriptorProxy.__getattr__(self, _PydanticDescriptorProxy__name)
#     204 def __getattr__(self, __name: str) -> Any:
#     205     """Forward checks for __isabstractmethod__ and such."""
# --> 206     return getattr(self.wrapped, __name)
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/_internal/_decorators.py:206, in PydanticDescriptorProxy.__getattr__(self, _PydanticDescriptorProxy__name)
#     204 def __getattr__(self, __name: str) -> Any:
#     205     """Forward checks for __isabstractmethod__ and such."""
# --> 206     return getattr(self.wrapped, __name)
#
#     [... skipping similar frames: PydanticDescriptorProxy.__getattr__ at line 206 (2943 times)]
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pydantic/_internal/_decorators.py:206, in PydanticDescriptorProxy.__getattr__(self, _PydanticDescriptorProxy__name)
#     204 def __getattr__(self, __name: str) -> Any:
#     205     """Forward checks for __isabstractmethod__ and such."""
# --> 206     return getattr(self.wrapped, __name)
#
# RecursionError: maximum recursion depth exceeded
