# %%
import pandas as pd

pd.read_csv('metrics_table.csv')
# Out:
#                             models      ndcg  precision@10    map@10  \
# 0                             bm25  0.766982           0.6  0.495536
# 1                 all-MiniLM-L6-v2  0.758008           0.4  0.369907
# 2               deepvk/USER-bge-m3  0.997123           1.0  0.714286
# 3   intfloat/multilingual-e5-large  0.984870           0.9  0.577593
# 4  Tochka-AI/ruRoPEBert-e5-base-2k  0.948111           0.7  0.636364
# 5        cointegrated/rubert-tiny2  0.584725           0.4  0.233796
#
#    recall@10  mrr@10    dcg@10
# 0   0.750000    0.50  2.552177
# 1   0.666667    1.00  2.003348
# 2   0.714286    1.00  4.543559
# 3   0.600000    1.00  4.210226
# 4   0.636364    1.00  3.638000
# 5   0.666667    0.25  1.403379
